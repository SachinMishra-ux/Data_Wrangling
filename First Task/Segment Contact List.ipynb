# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("Healthcare-Pharma-Research-Consulting-Transportation.xlsx")

# %%
df
# Out:
#           Contact Name First Name  Last Name                            Email  \
# 0          Tony Thomas       Tony     Thomas      tthomas@welcomehouseinc.org
# 1      Krystal Hadaway    Krystal    Hadaway  ktebedo@healthsourcesaginaw.org
# 2          Kate Mccann       Kate     Mccann   kmccann@washingtonhospital.org
# 3       Sheila Lambert     Sheila    Lambert    sheilalambert@texashealth.org
# 4      Laura Honeycutt      Laura  Honeycutt        lhoneycutt@sampsonrmc.org
# ...                ...        ...        ...                              ...
# 12272    Juan Montalvo       Juan   Montalvo                  jpmontal@up.com
# 12273        Scott Jay      Scott        Jay       scottjay@shannonhealth.org
# 12274      David Horak      David      Horak        david.horak@thedacare.org
# 12275       Amber Crum      Amber       Crum               amber.crum@tmh.org
# 12276     Olga Modders       Olga    Modders     omodders@hospiceofmarion.com
#
# ...

# %%
df1 = df.drop(['Contact Name','Address','City','State','Zip Code','Country','Fax Number','Web Site','Revenue'],axis='columns')
df1.shape
# Out:
# (12277, 8)

# %%
df1.describe()
# Out:
#        First Name Last Name                        Email  \
# count       12277     12277                        12277
# unique       2810      8082                        12277
# top          John     Smith  tthomas@welcomehouseinc.org
# freq          192        73                            1
#
#                                    Title              Company Name  \
# count                              12277                     12277
# unique                                 9                      5188
# top     Learning and Development Manager  Bdp International, Inc.
# freq                                2434                         8
#
#            Phone Number  Employees    Industry
# count             12271       9866       12277
# unique             4995        368           5
# top     +1-281-618-3100  250 - 500  Healthcare
# freq                 12       5390        6637

# %%
if df1.isnull().sum().any()>0:
    print("True")
# Out:
# True

# %%
df1.isnull()
# Out:
#        First Name  Last Name  Email  Title  Company Name  Phone Number  \
# 0           False      False  False  False         False         False
# 1           False      False  False  False         False         False
# 2           False      False  False  False         False         False
# 3           False      False  False  False         False         False
# 4           False      False  False  False         False         False
# ...           ...        ...    ...    ...           ...           ...
# 12272       False      False  False  False         False         False
# 12273       False      False  False  False         False         False
# 12274       False      False  False  False         False         False
# 12275       False      False  False  False         False         False
# 12276       False      False  False  False         False         False
#
#        Employees  Industry
# 0          False     False
# 1          False     False
# 2           True     False
# ...

# %%
df1['Industry'] = df1['Industry'].replace(['Pharma'],'Healthcare')

# %%
df1['Industry'] = df1['Industry'].replace(['Research'],'Healthcare')

# %%
df1['Industry'] = df1['Industry'].replace(['Consulting'],'Professional Services')

# %%
df1
# Out:
#       First Name  Last Name                            Email  \
# 0           Tony     Thomas      tthomas@welcomehouseinc.org
# 1        Krystal    Hadaway  ktebedo@healthsourcesaginaw.org
# 2           Kate     Mccann   kmccann@washingtonhospital.org
# 3         Sheila    Lambert    sheilalambert@texashealth.org
# 4          Laura  Honeycutt        lhoneycutt@sampsonrmc.org
# ...          ...        ...                              ...
# 12272       Juan   Montalvo                  jpmontal@up.com
# 12273      Scott        Jay       scottjay@shannonhealth.org
# 12274      David      Horak        david.horak@thedacare.org
# 12275      Amber       Crum               amber.crum@tmh.org
# 12276       Olga    Modders     omodders@hospiceofmarion.com
#
#                                       Title  \
# 0                                       CIO
# 1      Director Of Learning and Development
# 2         Learning and Development Director
# 3          Learning and Development Manager
# ...

# %%
df1['Industry'].unique()
# Out:
# array(['Healthcare', 'Transportation', 'Professional Services'],
#       dtype=object)

# %%
print(df1['Employees'].unique())
# Out:
# ['250 - 500' nan '500 - 1000' '2.1k' '800' '6.5k' '2k' '300' '160' '29k'
#  '8k' '850' '3k' '3.4k' '720' '900' '450' '16k' '1.1k' '25k' '2.5k' '515'
#  '4k' '280' '13k' '6.4k' '2.4k' '210' '3.5k' '881' '14k' '342k' '725'
#  '249' '4.1k' '6.1k' '520' '653' '4.5k' '100' '2.2k' '55k' '320' '5.5k'
#  '107' '975' '200' '6k' '113k' '1.5k' '1.7k' '3.2k' '500' '400' '1.3k'
#  '1k' '4.7k' '2.6k' '24k' '690' '570' '4.4k' '9.3k' '166' '201' '480'
#  '660' '280k' '3.3k' '170' '600' '21k' '1.2k' '350' '474' '66k' '5k' '42k'
#  '90k' '7.8k' '129' '2.7k' '9k' '654' '4.9k' '402' '20k' '840' '85k' '444'
#  '760' '386' '10k' '591' '12k' '18k' '37k' '950' '825' '7k' '435' '11k'
#  '892' '639' '412' '535' '687' '1.4k' '2.3k' '700' '64k' '432' '1.8k'
#  '8.6k' '645' '891' '651' '4.8k' '610' '880' '382' '23k' '2.8k' '295'
#  '650' '15k' '177' '19k' '420' '5.9k' '309' '618' '372' '1.6k' '749'
#  '1.9k' '360' '532' '178' '232' '5.3k' '130' '5.1k' '240' '377' '62k'
# ...

# %%
df2=df1

# %%
df2
# Out:
#       First Name  Last Name                            Email  \
# 0           Tony     Thomas      tthomas@welcomehouseinc.org
# 1        Krystal    Hadaway  ktebedo@healthsourcesaginaw.org
# 2           Kate     Mccann   kmccann@washingtonhospital.org
# 3         Sheila    Lambert    sheilalambert@texashealth.org
# 4          Laura  Honeycutt        lhoneycutt@sampsonrmc.org
# ...          ...        ...                              ...
# 12272       Juan   Montalvo                  jpmontal@up.com
# 12273      Scott        Jay       scottjay@shannonhealth.org
# 12274      David      Horak        david.horak@thedacare.org
# 12275      Amber       Crum               amber.crum@tmh.org
# 12276       Olga    Modders     omodders@hospiceofmarion.com
#
#                                       Title  \
# 0                                       CIO
# 1      Director Of Learning and Development
# 2         Learning and Development Director
# 3          Learning and Development Manager
# ...

# %%
df2['Employees_New']=df2['Employees']

# %%
df2
# Out:
#       First Name  Last Name                            Email  \
# 0           Tony     Thomas      tthomas@welcomehouseinc.org
# 1        Krystal    Hadaway  ktebedo@healthsourcesaginaw.org
# 2           Kate     Mccann   kmccann@washingtonhospital.org
# 3         Sheila    Lambert    sheilalambert@texashealth.org
# 4          Laura  Honeycutt        lhoneycutt@sampsonrmc.org
# ...          ...        ...                              ...
# 12272       Juan   Montalvo                  jpmontal@up.com
# 12273      Scott        Jay       scottjay@shannonhealth.org
# 12274      David      Horak        david.horak@thedacare.org
# 12275      Amber       Crum               amber.crum@tmh.org
# 12276       Olga    Modders     omodders@hospiceofmarion.com
#
#                                       Title  \
# 0                                       CIO
# 1      Director Of Learning and Development
# 2         Learning and Development Director
# 3          Learning and Development Manager
# ...

# %%
df2.Employees_New = df2.Employees_New.fillna('10000000000')

# %%
df2.isnull().sum()
# Out:
# First Name          0
# Last Name           0
# Email               0
# Title               0
# Company Name        0
# Phone Number        6
# Employees        2411
# Industry            0
# Employees_New       0
# dtype: int64

# %%
df2
# Out:
#       First Name  Last Name                            Email  \
# 0           Tony     Thomas      tthomas@welcomehouseinc.org
# 1        Krystal    Hadaway  ktebedo@healthsourcesaginaw.org
# 2           Kate     Mccann   kmccann@washingtonhospital.org
# 3         Sheila    Lambert    sheilalambert@texashealth.org
# 4          Laura  Honeycutt        lhoneycutt@sampsonrmc.org
# ...          ...        ...                              ...
# 12272       Juan   Montalvo                  jpmontal@up.com
# 12273      Scott        Jay       scottjay@shannonhealth.org
# 12274      David      Horak        david.horak@thedacare.org
# 12275      Amber       Crum               amber.crum@tmh.org
# 12276       Olga    Modders     omodders@hospiceofmarion.com
#
#                                       Title  \
# 0                                       CIO
# 1      Director Of Learning and Development
# 2         Learning and Development Director
# 3          Learning and Development Manager
# ...

# %%
def convert_employees(x):
    if '-' in x:
        tokens = x.split('-')
        return (float(tokens[1]))
    elif 'k' in x:
        tokens =x.split('k')
        return float(tokens[0])*1000
    else:
        return float(x)

# %%
df2.Employees_New = df2.Employees_New.apply(convert_employees)

# %%
df2
# Out:
#       First Name  Last Name                            Email  \
# 0           Tony     Thomas      tthomas@welcomehouseinc.org
# 1        Krystal    Hadaway  ktebedo@healthsourcesaginaw.org
# 2           Kate     Mccann   kmccann@washingtonhospital.org
# 3         Sheila    Lambert    sheilalambert@texashealth.org
# 4          Laura  Honeycutt        lhoneycutt@sampsonrmc.org
# ...          ...        ...                              ...
# 12272       Juan   Montalvo                  jpmontal@up.com
# 12273      Scott        Jay       scottjay@shannonhealth.org
# 12274      David      Horak        david.horak@thedacare.org
# 12275      Amber       Crum               amber.crum@tmh.org
# 12276       Olga    Modders     omodders@hospiceofmarion.com
#
#                                       Title  \
# 0                                       CIO
# 1      Director Of Learning and Development
# 2         Learning and Development Director
# 3          Learning and Development Manager
# ...

# %%
df2.drop(df2[df2['Employees_New'] > 500].index, inplace = True)

# %%
df2
# Out:
#       First Name Last Name                               Email  \
# 0           Tony    Thomas         tthomas@welcomehouseinc.org
# 1        Krystal   Hadaway     ktebedo@healthsourcesaginaw.org
# 7         Dontai      Nash             dontai.nash@walmart.com
# 8          Bryan   Munchel       bmunchel@postacutemedical.com
# 9        Rebecca    Baxter            rebecca_baxter@flpps.org
# ...          ...       ...                                 ...
# 12265   Kimberly   Anthony  kimberly.anthony@aprevahospice.com
# 12267     Lorrie     Roddy              lroddy@intlfreight.net
# 12270   Krietsch  Michelle  michelle_krietsch@apllogistics.com
# 12272       Juan  Montalvo                     jpmontal@up.com
# 12276       Olga   Modders        omodders@hospiceofmarion.com
#
#                                       Title  \
# 0                                       CIO
# 1      Director Of Learning and Development
# 7          Learning and Development Manager
# ...

# %%
file_name = 'less than five hundred.xlsx'
df2.to_excel(file_name)

# %%
df10=pd.read_excel("greater than five hundred.xlsx")

# %%
df10
# Out:
#       Unnamed: 0 First Name  Last Name                           Email  \
# 0              2       Kate     Mccann  kmccann@washingtonhospital.org
# 1              3     Sheila    Lambert   sheilalambert@texashealth.org
# 2              4      Laura  Honeycutt       lhoneycutt@sampsonrmc.org
# 3              5     Warren   Robinson     wrobinson@mauryregional.com
# 4              6       Tara     Gilroy      tgilroy@mvhealthsystem.org
# ...          ...        ...        ...                             ...
# 6312       12269     Rachel      Money             rmoney@iuhealth.org
# 6313       12271     Joseph    Rudolph                 josephr@ccf.org
# 6314       12273      Scott        Jay      scottjay@shannonhealth.org
# 6315       12274      David      Horak       david.horak@thedacare.org
# 6316       12275      Amber       Crum              amber.crum@tmh.org
#
#                                   Title  \
# 0     Learning and Development Director
# ...

# %%
df11 = df10.drop(df10[(df10['Industry'] == 'Healthcare') | (df10['Industry'] == 'Transportation')].index)

# %%
df11
# Out:
#       Unnamed: 0 First Name Last Name                                Email  \
# 14            28      Tyler    Lummis                 tlummis@deloitte.com
# 31            58       John       Kim                    john.kim@adpt.com
# 40            74       Adam  Olivares               adam.olivares@adpt.com
# 44            79      Kamie   Sickels             sickelk@sutterhealth.org
# 83           160       Zach    Savage       zsavage@westmonroepartners.com
# ...          ...        ...       ...                                  ...
# 6108       11877    Darlene   Hawkins       darlene.hawkins@leonagroup.com
# 6286       12225       Atiq  Abdullah               atiq.abdullah@akqa.com
# 6293       12237      David    Zakson  david.zakson@westmonroepartners.com
# 6294       12240     Elaine    Cheung          elaine.cheung@multiplan.com
# 6302       12252        Bob     Chess                   bchess@acrtinc.com
#
# ...

# %%
df40=pd.read_excel("less than five hundred.xlsx")

# %%
df40
# Out:
#       Unnamed: 0 First Name Last Name                               Email  \
# 0              0       Tony    Thomas         tthomas@welcomehouseinc.org
# 1              1    Krystal   Hadaway     ktebedo@healthsourcesaginaw.org
# 2              7     Dontai      Nash             dontai.nash@walmart.com
# 3              8      Bryan   Munchel       bmunchel@postacutemedical.com
# 4              9    Rebecca    Baxter            rebecca_baxter@flpps.org
# ...          ...        ...       ...                                 ...
# 5955       12265   Kimberly   Anthony  kimberly.anthony@aprevahospice.com
# 5956       12267     Lorrie     Roddy              lroddy@intlfreight.net
# 5957       12270   Krietsch  Michelle  michelle_krietsch@apllogistics.com
# 5958       12272       Juan  Montalvo                     jpmontal@up.com
# 5959       12276       Olga   Modders        omodders@hospiceofmarion.com
#
#                                      Title  \
# ...

# %%
df41 = df40.drop(df40[(df40['Industry'] == 'Transportation') | (df40['Industry'] == 'Healthcare')].index)

# %%
df41
# Out:
#       Unnamed: 0 First Name Last Name                          Email  \
# 4              9    Rebecca    Baxter       rebecca_baxter@flpps.org
# 37            90        Liz    Nannen       l.nannen@strategichs.com
# 46           110       Paul    Waters  pwaters@waltoncommunities.com
# 49           114      Susan     Gowen            sgowen@ekhealth.com
# 51           116      Missy     Peyer             mpeyer@adreima.com
# ...          ...        ...       ...                            ...
# 5897       12143     Masako   Cornett    masako.cornett@pacgroup.com
# 5899       12146    Cynthia  Martinez    cmartinez@powerwellness.com
# 5906       12156    Barbara     Lewer   barbara.lewer@omvmedical.com
# 5922       12185     Jeremy   Preston              jdpreston@dow.com
# 5940       12229    Michael      Bowe   michaelb@resourceone-llc.com
#
#                                      Title  \
# 4                              L&D Manager
# 37        Learning and Development Manager
# ...

# %%
file_name = 'Professional Services.xlsx'
df41.to_excel(file_name)

# %%
df50=pd.read_excel("Healthcare-Research-Transportation-Data-Snap-List-2.xlsx")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 df50=pd.read_excel("Healthcare-Research-Transportation-Data-Snap-List-2.xlsx",sheet='Sheet1')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: read_excel() got an unexpected keyword argument 'sheet'

# %%
df50
# Out:
#            Contact Name First Name  Last Name  \
# 0         Steven Heiman     Steven     Heiman
# 1              Ed Ricks         Ed      Ricks
# 2         R P Balakumar          R  Balakumar
# 3           Paul Slater       Paul     Slater
# 4       Karine Aylozyan     Karine   Aylozyan
# ...                 ...        ...        ...
# 4853  Katherine Lustila  Katherine    Lustila
# 4854          Jo Convis         Jo     Convis
# 4855       Matthew Fine    Matthew       Fine
# 4856     Ying D Higgins       Ying    Higgins
# 4857        Phil Dougan       Phil     Dougan
#
#                                 Email                              Title  \
# 0          sheiman@matherhospital.org     Head, Learning and Development
# 1                    ericks@bmhsc.org   Learning and Development Manager
# 2             r.balakumar@sailife.com   Learning and Development Manager
# 3                 pslater@aimntls.com                                CIO
# ...

# %%
df50['Industry'].unique()
# Out:
# array(['Healthcare', 'Pharma', 'Transportation'], dtype=object)

# %%
df50['Industry'] = df50['Industry'].replace(['Pharma'],'Healthcare')

# %%
print(df50['Employees'].unique())
# Out:
# ['>10,000' '1,000 - 5,000' '2K - 10K' '> 10,000' '5,000 - 10,000'
#  '1,000-5,000' '1,380' '1K - 10K' '1,000 - 2,500' '50K - 100K' '5,000'
#  '10,000' '> 1,000' 'Over 10,000' '10K - 50K' '3,000' '1,000 - 2000'
#  '6,000' '>1,000' '> 100K' '2,500 - 5,000' '2,340' '1,000' '2,000 - 4,000'
#  '2,000' '5000 - 10,000' '9,070' '6,100' '1,000 - $5,000' '1,395'
#  '5,000 - 7,500' '59,076' '58,000' '1,539' '2,670' '100 - 5,000' '1,980'
#  '5,000-10,000' '3,900' '10,800' '1,445' '6,342' '1,550' '7,299' '1,200'
#  '9,800' '19,000' 'Over10,000' '3,650' '2,300' '80,723' 1000]

# %%
df50.isnull().sum()
# Out:
# Contact Name       0
# First Name         0
# Last Name          0
# Email              0
# Title              0
# Company Name       0
# Phone Number       0
# Fax Number      1760
# Web Site           0
# Revenue          970
# Employees          0
# Industry           0
# dtype: int64

# %%
df51=df50

# %%
df51['Employees_New']=df51['Employees']

# %%
df51
# Out:
#            Contact Name First Name  Last Name  \
# 0         Steven Heiman     Steven     Heiman
# 1              Ed Ricks         Ed      Ricks
# 2         R P Balakumar          R  Balakumar
# 3           Paul Slater       Paul     Slater
# 4       Karine Aylozyan     Karine   Aylozyan
# ...                 ...        ...        ...
# 4853  Katherine Lustila  Katherine    Lustila
# 4854          Jo Convis         Jo     Convis
# 4855       Matthew Fine    Matthew       Fine
# 4856     Ying D Higgins       Ying    Higgins
# 4857        Phil Dougan       Phil     Dougan
#
#                                 Email                              Title  \
# 0          sheiman@matherhospital.org     Head, Learning and Development
# 1                    ericks@bmhsc.org   Learning and Development Manager
# 2             r.balakumar@sailife.com   Learning and Development Manager
# 3                 pslater@aimntls.com                                CIO
# ...

# %%
#x='1K - 10K'
#x1='1,000 - 5,000'
x2='1,000 - $5,000'
l=x2.split('-')
#for i in l:
 #   print(i)
f=l[1].strip()  
final=f.split('$')
final1=(final[1])
eval(final1)
# Out:
# (5, 0)

# %%
z='5,000'
eval(z)
# Out:
# (5, 0)

# %%
y='>10,000'
tokens=y.split('>')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 3>()
#       1 y='>10,000'
#       2 tokens=y.split('>')
# ----> 3 float(tokens[1])
#
# ValueError: could not convert string to float: '10,000'

# %%
def convert_employees(x):
    if 'K' in x:
        tokens = x.split('K')
        if 'K' in f:
            final=f.split('K')
            return float(final[0])
    elif '>' in x:
        tokens =x.split('>')
        return float(tokens[0])*1000
    else:
        return float(x)

# %%
df2.Employees_New = df2.Employees_New.apply(convert_employees)

# %%
xls = pd.ExcelFile('Healthcare-Research-Transportation-Data-Snap-List-2.xlsx')
df70 = pd.read_excel(xls, 'Sheet1')

# %%
df70
# Out:
#            Employees  Unnamed: 1 Extracted      Employees0 Unnamed: 4  \
# 0            >10,000         NaN    10,000             NaN      10000
# 1            >10,000         NaN    10,000             NaN      10000
# 2      1,000 - 5,000         NaN     5,000   1,000 - 5,000        NaN
# 3      1,000 - 5,000         NaN     5,000   1,000 - 5,000        NaN
# 4            >10,000         NaN    10,000             NaN      10000
# ...              ...         ...       ...             ...        ...
# 4853   1,000 - 5,000         NaN     5,000   1,000 - 5,000        NaN
# 4854         >10,000         NaN    10,000             NaN      10000
# 4855         >10,000         NaN    10,000             NaN      10000
# 4856        > 10,000         NaN    10,000             NaN      10000
# 4857  5,000 - 10,000         NaN    10,000  5,000 - 10,000        NaN
#
#      Employees1 Unnamed: 6 Emplyees_Final    Emp
# 0           NaN        NaN          10000  10000
# ...

# %%
df70.isnull().sum()
# Out:
# Employees            0
# Unnamed: 1        4858
# Extracted            0
# Employees0        2237
# Unnamed: 4        2621
# Employees1        2237
# Unnamed: 6        2452
# Emplyees_Final       0
# Emp                  0
# dtype: int64

# %%
print(df70['Emp'].unique())
# Out:
# ['10000' '5000' '10K' '1380' '2500' '100K' '1000' '100000000' '50K' '3000'
#  '2000' '6000' '2340' '4000' '9070' '6100' '1395' '7500' '59076' '58000'
#  '1539' '2670' '1980' '3900' '10800' '1445' '6342' '1550' '7299' '1200'
#  '9800' '19000' '3650' '2300' '80723']

# %%
df70['Emplyees_Final'] = df70['Emplyees_Final'].replace([' $5,000'],5000)

# %%
print(df70['Emp'].unique())
# Out:
# ['10000' '5000' '10K' '1380' '2500' '100K' '1000' '100000000' '50K' '3000'
#  '2000' '6000' '2340' '4000' '9070' '6100' '1395' '7500' '59076' '58000'
#  '1539' '2670' '1980' '3900' '10800' '1445' '6342' '1550' '7299' '1200'
#  '9800' '19000' '3650' '2300' '80723']

# %%
def convert_employees(x):
    try:
        if 'K' in x:
            tokens = x.split('K')
            return float(tokens[0])*1000
        else:
            return float(x)
    except:    
        return float(x)

# %%
a='10K'
b=a.split('K')
e=int(b[0]*1000)
e
# Out:
# ...

# %%
df70.Emp = df70.Emp.apply(convert_employees)

# %%
df70
# Out:
#            Employees  Unnamed: 1 Extracted      Employees0 Unnamed: 4  \
# 0            >10,000         NaN    10,000             NaN      10000
# 1            >10,000         NaN    10,000             NaN      10000
# 2      1,000 - 5,000         NaN     5,000   1,000 - 5,000        NaN
# 3      1,000 - 5,000         NaN     5,000   1,000 - 5,000        NaN
# 4            >10,000         NaN    10,000             NaN      10000
# ...              ...         ...       ...             ...        ...
# 4853   1,000 - 5,000         NaN     5,000   1,000 - 5,000        NaN
# 4854         >10,000         NaN    10,000             NaN      10000
# 4855         >10,000         NaN    10,000             NaN      10000
# 4856        > 10,000         NaN    10,000             NaN      10000
# 4857  5,000 - 10,000         NaN    10,000  5,000 - 10,000        NaN
#
#      Employees1 Unnamed: 6 Emplyees_Final      Emp
# 0           NaN        NaN          10000  10000.0
# ...

# %%
print(df70['Emp'].unique())
# Out:
# [1.0000e+04 5.0000e+03 1.3800e+03 2.5000e+03 1.0000e+05 1.0000e+03
#  1.0000e+08 5.0000e+04 3.0000e+03 2.0000e+03 6.0000e+03 2.3400e+03
#  4.0000e+03 9.0700e+03 6.1000e+03 1.3950e+03 7.5000e+03 5.9076e+04
#  5.8000e+04 1.5390e+03 2.6700e+03 1.9800e+03 3.9000e+03 1.0800e+04
#  1.4450e+03 6.3420e+03 1.5500e+03 7.2990e+03 1.2000e+03 9.8000e+03
#  1.9000e+04 3.6500e+03 2.3000e+03 8.0723e+04]

# %%
df70
# Out:
#            Employees  Unnamed: 1 Extracted      Employees0 Unnamed: 4  \
# 0            >10,000         NaN    10,000             NaN      10000
# 1            >10,000         NaN    10,000             NaN      10000
# 2      1,000 - 5,000         NaN     5,000   1,000 - 5,000        NaN
# 3      1,000 - 5,000         NaN     5,000   1,000 - 5,000        NaN
# 4            >10,000         NaN    10,000             NaN      10000
# ...              ...         ...       ...             ...        ...
# 4853   1,000 - 5,000         NaN     5,000   1,000 - 5,000        NaN
# 4854         >10,000         NaN    10,000             NaN      10000
# 4855         >10,000         NaN    10,000             NaN      10000
# 4856        > 10,000         NaN    10,000             NaN      10000
# 4857  5,000 - 10,000         NaN    10,000  5,000 - 10,000        NaN
#
#      Employees1 Unnamed: 6 Emplyees_Final      Emp
# 0           NaN        NaN          10000  10000.0
# ...

# %%
file_name = 'Emp_Final.xlsx'
df70.to_excel(file_name)

# %%
df=pd.read_excel("Healthcare-Research-Transportation-Data-Snap-List-2.xlsx")

# %%
df
# Out:
#            Contact Name First Name  Last Name  \
# 0         Steven Heiman     Steven     Heiman
# 1              Ed Ricks         Ed      Ricks
# 2         R P Balakumar          R  Balakumar
# 3           Paul Slater       Paul     Slater
# 4       Karine Aylozyan     Karine   Aylozyan
# ...                 ...        ...        ...
# 4853  Katherine Lustila  Katherine    Lustila
# 4854          Jo Convis         Jo     Convis
# 4855       Matthew Fine    Matthew       Fine
# 4856     Ying D Higgins       Ying    Higgins
# 4857        Phil Dougan       Phil     Dougan
#
#                                 Email                              Title  \
# 0          sheiman@matherhospital.org     Head, Learning and Development
# 1                    ericks@bmhsc.org   Learning and Development Manager
# 2             r.balakumar@sailife.com   Learning and Development Manager
# 3                 pslater@aimntls.com                                CIO
# ...

# %%
df['Industry'] = df['Industry'].replace(['Pharma'],'Healthcare')

# %%
df
# Out:
#            Contact Name First Name  Last Name  \
# 0         Steven Heiman     Steven     Heiman
# 1              Ed Ricks         Ed      Ricks
# 2         R P Balakumar          R  Balakumar
# 3           Paul Slater       Paul     Slater
# 4       Karine Aylozyan     Karine   Aylozyan
# ...                 ...        ...        ...
# 4853  Katherine Lustila  Katherine    Lustila
# 4854          Jo Convis         Jo     Convis
# 4855       Matthew Fine    Matthew       Fine
# 4856     Ying D Higgins       Ying    Higgins
# 4857        Phil Dougan       Phil     Dougan
#
#                                 Email                              Title  \
# 0          sheiman@matherhospital.org     Head, Learning and Development
# 1                    ericks@bmhsc.org   Learning and Development Manager
# 2             r.balakumar@sailife.com   Learning and Development Manager
# 3                 pslater@aimntls.com                                CIO
# ...

# %%
df1=df

# %%
df1.drop(df1[df1['Emp'] <5000].index, inplace = True) #under 5k
#df2.drop(df2[df2['Employees_New'] > 500].index, inplace = True)

# %%
df1
# Out:
#            Contact Name First Name  Last Name  \
# 0         Steven Heiman     Steven     Heiman
# 1              Ed Ricks         Ed      Ricks
# 2         R P Balakumar          R  Balakumar
# 3           Paul Slater       Paul     Slater
# 4       Karine Aylozyan     Karine   Aylozyan
# ...                 ...        ...        ...
# 4853  Katherine Lustila  Katherine    Lustila
# 4854          Jo Convis         Jo     Convis
# 4855       Matthew Fine    Matthew       Fine
# 4856     Ying D Higgins       Ying    Higgins
# 4857        Phil Dougan       Phil     Dougan
#
#                                 Email                              Title  \
# 0          sheiman@matherhospital.org     Head, Learning and Development
# 1                    ericks@bmhsc.org   Learning and Development Manager
# 2             r.balakumar@sailife.com   Learning and Development Manager
# 3                 pslater@aimntls.com                                CIO
# ...

# %%
df1.drop(df1[df1['Emp'] >=10000].index, inplace = True)

# %%
df1
# Out:
#               Contact Name First Name      Last Name  \
# 2            R P Balakumar          R      Balakumar
# 3              Paul Slater       Paul         Slater
# 7        Brian L Helleland      Brian      Helleland
# 8          James Pelliccio      James      Pelliccio
# 9            Jenna Haymond      Jenna        Haymond
# ...                    ...        ...            ...
# 4844         Sandra Kopacz     Sandra         Kopacz
# 4845         Penny O'Neill      Penny        O'Neill
# 4847  Sheela Garudaiyengar     Sheela  Garudaiyengar
# 4850           Betsy Frost      Betsy          Frost
# 4853     Katherine Lustila  Katherine        Lustila
#
#                                     Email                              Title  \
# 2                 r.balakumar@sailife.com   Learning and Development Manager
# 3                     pslater@aimntls.com                                CIO
# 7               brian.helleland@stjoe.org     Head, Learning and Development
# ...

# %%
df2=df1

# %%
df2
# Out:
#               Contact Name First Name      Last Name  \
# 2            R P Balakumar          R      Balakumar
# 3              Paul Slater       Paul         Slater
# 7        Brian L Helleland      Brian      Helleland
# 8          James Pelliccio      James      Pelliccio
# 9            Jenna Haymond      Jenna        Haymond
# ...                    ...        ...            ...
# 4844         Sandra Kopacz     Sandra         Kopacz
# 4845         Penny O'Neill      Penny        O'Neill
# 4847  Sheela Garudaiyengar     Sheela  Garudaiyengar
# 4850           Betsy Frost      Betsy          Frost
# 4853     Katherine Lustila  Katherine        Lustila
#
#                                     Email                              Title  \
# 2                 r.balakumar@sailife.com   Learning and Development Manager
# 3                     pslater@aimntls.com                                CIO
# 7               brian.helleland@stjoe.org     Head, Learning and Development
# ...

# %%
df3 = df2.drop(df2[(df2['Industry'] == 'Healthcare')].index) # This is for Transportation

# %%
df3
# Out:
#            Contact Name First Name      Last Name  \
# 3           Paul Slater       Paul         Slater
# 8       James Pelliccio      James      Pelliccio
# 15           Dana Hofer       Dana          Hofer
# 70     Vicki Carmichael      Vicki     Carmichael
# 85          Julie Sieja      Julie          Sieja
# ...                 ...        ...            ...
# 4807  Bob Vallandingham        Bob  Vallandingham
# 4814       Sam Crompton        Sam       Crompton
# 4826       Doni Cornett       Doni        Cornett
# 4835         Carl Allen       Carl          Allen
# 4850        Betsy Frost      Betsy          Frost
#
#                                          Email  \
# 3                          pslater@aimntls.com
# 8                     james.pelliccio@pnct.net
# 15                          dhofer@mtm-inc.net
# 70                        vickic@silversea.com
# 85                       jsieja@jackcooper.com
# ...                                        ...
# ...

# %%
file_name = 'Transportation_5kto10k.xlsx'
df3.to_excel(file_name)
