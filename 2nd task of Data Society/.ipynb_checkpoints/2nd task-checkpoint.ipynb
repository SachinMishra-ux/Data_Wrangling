# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("Fastbase_business_contacts_excel_699_HVVPQG.xlsx")

# %%
df
# Out:
#               FULL NAME First Name   Last Name  \
# 0       Linda Iasouvanh     Linda    Iasouvanh
# 1       Benjamin Yarish  Benjamin       Yarish
# 2     Waseem Abou-Marie    Waseem   Abou-Marie
# 3         Meggan Levitt    Meggan       Levitt
# 4             Jeri Dunn      Jeri         Dunn
# ...                 ...        ...         ...
# 4062         Nada Daman      Nada        Daman
# 4063   Steven Fulkerson    Steven    Fulkerson
# 4064         Sam Segran       Sam       Segran
# 4065       Diane Hanson     Diane       Hanson
# 4066       Debbie Dertz    Debbie        Dertz
#
#                                               JOB TITLE  \
# 0                Learning and Development Manager - Anz
# 1     Chief, Chief Information Officer Enterprise Re...
# 2     Group Chief Information Officer - Middle East,...
# 3     Assistant Vice Provost and Associate Chief Inf...
# 4     Senior Vice President and Chief Information Of...
# ...

# %%
df.isnull().sum()
# Out:
# FULL NAME              0
# First Name             0
# Last Name              0
# JOB TITLE              0
# COMPANY CATEGORY     125
# COMPANY NAME           0
# EMAIL                  0
# First EMAIL            0
# Second Email        2185
# Third               3445
# Fourth              3844
# Unnamed: 11         3995
# Unnamed: 12         4034
# Unnamed: 13         4056
# Unnamed: 14         4062
# Unnamed: 15         4065
# Unnamed: 16         4066
# dtype: int64

# %%
len(df['COMPANY CATEGORY'].unique())
# Out:
# 121

# %%
l=df['COMPANY CATEGORY'].unique()
for i in l:
    print(i)
# Out:
# Human Resources
# Information Technology and Services
# Higher Education
# Food Production
# Marketing and Advertising
# Government and Federal
# Writing and Editing
# Hospital Health Care
# Hospitality
# Investment Banking
# Financial Services
# Military
# International Development
# Restaurants
# Transportation
# Media and Telecommunications
# Outsourcing/Offshoring
# Education Management
# Aerospace and Defense
# Renewables Environment
# Airlines/Aviation
# nan
# Insurance
# Professional Training Coaching
# Non-Profit Organization Management
# Internet
# Construction
# Computer Software
# Computer Networking
# Law Practice
# Pharmaceuticals
# Leisure, Travel, Tourism
# Gambling Casinos
# Management Consulting
# Sporting Goods
# Music
# Executive Office
# Supply Chain
# Medical Devices
# Facilities Services
# Oil Energy
# E-Learning
# Investment Management
# Consumer Electronics
# Apparel Fashion
# Telecommunications
# Security and Investigations
# Public Safety
# Research
# ...

# %%
df['COMPANY CATEGORY'] = df['COMPANY CATEGORY'].replace(['Government Administration'],'Government and Federal')

df['COMPANY CATEGORY'] = df['COMPANY CATEGORY'].replace(['Defense Space'],'Aerospace and Defense')

df['COMPANY CATEGORY'] = df['COMPANY CATEGORY'].replace(['Aviation Aerospace'],'Aerospace and Defense')

df['COMPANY CATEGORY'] = df['COMPANY CATEGORY'].replace(['Utilities'],'Media and Telecommunications')

df['COMPANY CATEGORY'] = df['COMPANY CATEGORY'].replace(['Logistics and Supply Chain'],'Supply Chain')

df['COMPANY CATEGORY'] = df['COMPANY CATEGORY'].replace(['Building Materials'],'Energy and Mining and raw Materials')

df['COMPANY CATEGORY'] = df['COMPANY CATEGORY'].replace(['Electrical/Electronic Manufacturing'],'Manufacturing')

df['COMPANY CATEGORY'] = df['COMPANY CATEGORY'].replace(['Automotive'],'Transportation')

df['COMPANY CATEGORY'] = df['COMPANY CATEGORY'].replace(['Transportation/Trucking/Railroad'],'Transportation')

df['COMPANY CATEGORY'] = df['COMPANY CATEGORY'].replace(['Package/Freight Delivery'],'Supply Chain')

df['COMPANY CATEGORY'] = df['COMPANY CATEGORY'].replace(['Industrial Automation'],'Manufacturing')

df['COMPANY CATEGORY'] = df['COMPANY CATEGORY'].replace(['Import and Export'],'Supply Chain')

df['COMPANY CATEGORY'] = df['COMPANY CATEGORY'].replace(['International Trade and Development'],'International Development')


df['COMPANY CATEGORY'] = df['COMPANY CATEGORY'].replace(['Mechanical or Industrial Engineering'],'Manufacturing')

# %%
df
# Out:
#               FULL NAME First Name   Last Name  \
# 0       Linda Iasouvanh     Linda    Iasouvanh
# 1       Benjamin Yarish  Benjamin       Yarish
# 2     Waseem Abou-Marie    Waseem   Abou-Marie
# 3         Meggan Levitt    Meggan       Levitt
# 4             Jeri Dunn      Jeri         Dunn
# ...                 ...        ...         ...
# 4062         Nada Daman      Nada        Daman
# 4063   Steven Fulkerson    Steven    Fulkerson
# 4064         Sam Segran       Sam       Segran
# 4065       Diane Hanson     Diane       Hanson
# 4066       Debbie Dertz    Debbie        Dertz
#
#                                               JOB TITLE  \
# 0                Learning and Development Manager - Anz
# 1     Chief, Chief Information Officer Enterprise Re...
# 2     Group Chief Information Officer - Middle East,...
# 3     Assistant Vice Provost and Associate Chief Inf...
# 4     Senior Vice President and Chief Information Of...
# ...

# %%
df1=df

# %%
df1.rename(columns = {'First EMAIL':'First'}, inplace = True)

# %%
discard = ["@gmail.com"]

# %%
#df1.drop(df1[df1['First EMAIL'] == 500].index, inplace = True)
df1=df1[~df1.First.str.contains('|'.join(discard))]

# %%
df1
# Out:
#               FULL NAME First Name   Last Name  \
# 0       Linda Iasouvanh     Linda    Iasouvanh
# 1       Benjamin Yarish  Benjamin       Yarish
# 2     Waseem Abou-Marie    Waseem   Abou-Marie
# 3         Meggan Levitt    Meggan       Levitt
# 4             Jeri Dunn      Jeri         Dunn
# ...                 ...        ...         ...
# 4062         Nada Daman      Nada        Daman
# 4063   Steven Fulkerson    Steven    Fulkerson
# 4064         Sam Segran       Sam       Segran
# 4065       Diane Hanson     Diane       Hanson
# 4066       Debbie Dertz    Debbie        Dertz
#
#                                               JOB TITLE  \
# 0                Learning and Development Manager - Anz
# 1     Chief, Chief Information Officer Enterprise Re...
# 2     Group Chief Information Officer - Middle East,...
# 3     Assistant Vice Provost and Associate Chief Inf...
# 4     Senior Vice President and Chief Information Of...
# ...

# %%
discard1 = ["@yahoo.com"]

# %%
df1=df1[~df1.First.str.contains('|'.join(discard1))]

# %%
df1
# Out:
#               FULL NAME First Name   Last Name  \
# 0       Linda Iasouvanh     Linda    Iasouvanh
# 1       Benjamin Yarish  Benjamin       Yarish
# 2     Waseem Abou-Marie    Waseem   Abou-Marie
# 3         Meggan Levitt    Meggan       Levitt
# 4             Jeri Dunn      Jeri         Dunn
# ...                 ...        ...         ...
# 4062         Nada Daman      Nada        Daman
# 4063   Steven Fulkerson    Steven    Fulkerson
# 4064         Sam Segran       Sam       Segran
# 4065       Diane Hanson     Diane       Hanson
# 4066       Debbie Dertz    Debbie        Dertz
#
#                                               JOB TITLE  \
# 0                Learning and Development Manager - Anz
# 1     Chief, Chief Information Officer Enterprise Re...
# 2     Group Chief Information Officer - Middle East,...
# 3     Assistant Vice Provost and Associate Chief Inf...
# 4     Senior Vice President and Chief Information Of...
# ...

# %%
discard2 = ["@hotmail.com"]

# %%
df1=df1[df1.First.str.contains('|'.join(discard2))]

# %%
df1
# Out:
#             FULL NAME First Name Last Name  \
# 47         Rob Sprout       Rob     Sprout
# 83      Eugene Walker    Eugene     Walker
# 95     Sandra Roitman    Sandra    Roitman
# 102        Gary Pratt      Gary      Pratt
# 152     Aparna Kurada    Aparna     Kurada
# ...               ...        ...       ...
# 3930  Latressa Fulton  Latressa     Fulton
# 3958    Eric Phillips      Eric   Phillips
# 4000     Donald Patra    Donald      Patra
# 4006   Veena Rajkumar     Veena   Rajkumar
# 4029     Jill Johnson      Jill    Johnson
#
#                                               JOB TITLE  \
# 47    Da Chief Information Officer and G6 Chief, Int...
# 83    Chief Information Officer Ecosystem Products a...
# 95    Vice President and Chile Chief Information Off...
# 102                           Chief Information Officer
# 152   Chief Information Officer Lead For The Cogniti...
# ...                                                 ...
# ...

# %%
file_name = 'Working2hotmail.xlsx'
df1.to_excel(file_name)

# %%
df10=pd.read_excel("C:/Users/admin/Desktop/new/working1.xlsx")

# %%
df10
# Out:
#              FULL NAME First Name  Last Name  \
# 0      Linda Iasouvanh     Linda   Iasouvanh
# 1        Meggan Levitt    Meggan      Levitt
# 2            Jeri Dunn      Jeri        Dunn
# 3            Jill Cook      Jill        Cook
# 4       Patrick Dineen   Patrick      Dineen
# ...                ...        ...        ...
# 3485        Nada Daman      Nada       Daman
# 3486  Steven Fulkerson    Steven   Fulkerson
# 3487        Sam Segran       Sam      Segran
# 3488      Diane Hanson     Diane      Hanson
# 3489      Debbie Dertz    Debbie       Dertz
#
#                                               JOB TITLE  \
# 0                Learning and Development Manager - Anz
# 1     Assistant Vice Provost and Associate Chief Inf...
# 2     Senior Vice President and Chief Information Of...
# 3            Senior Learning and Development Specialist
# 4              Interim Global Chief Information Officer
# ...                                                 ...
# ...

# %%
df10.dtypes
# Out:
# FULL NAME           object
# First Name          object
# Last Name           object
# JOB TITLE           object
# COMPANY CATEGORY    object
# COMPANY NAME        object
# COMA                object
# COMPANYD            object
# EMAIL               object
# First               object
# Second Email        object
# Third               object
# Fourth              object
# Unnamed: 11         object
# Unnamed: 12         object
# Unnamed: 13         object
# Unnamed: 14         object
# Unnamed: 15         object
# Unnamed: 16         object
# dtype: object

# %%
import re

# %%
text= "tibor.szikszai@bankofthewest.com"
text.re.findall(pattern,text)

#l=re.findall(pattern,text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [105], in <cell line: 2>()
#       1 text= "tibor.szikszai@bankofthewest.com"
# ----> 2 text.re.findall(pattern,text)
#
# AttributeError: 'str' object has no attribute 're'

# %%
l[0]
# Out:
# 'bankofthewest'

# %%
df["exists"] = df.drop("First", 1).isin(df["First"]).any(1)

# %%
a='sachin19566@gmail.com'
a[-5:-8:-1][::-1]
# Out:
# 'ail'

# %%
def find_value_column(row):
    return row.First[-5:-8:-1][::-1] in row.COMPANYD

df11=df10[df10.apply(find_value_column, axis=1)]

# %%
df11
# Out:
#             FULL NAME First Name  Last Name  \
# 0     Linda Iasouvanh     Linda   Iasouvanh
# 2           Jeri Dunn      Jeri        Dunn
# 3           Jill Cook      Jill        Cook
# 4      Patrick Dineen   Patrick      Dineen
# 7          Ron Double       Ron      Double
# ...               ...        ...        ...
# 3480      Mindy Simon     Mindy       Simon
# 3482       Joe Dumara       Joe      Dumara
# 3485       Nada Daman      Nada       Daman
# 3488     Diane Hanson     Diane      Hanson
# 3489     Debbie Dertz    Debbie       Dertz
#
#                                               JOB TITLE  \
# 0                Learning and Development Manager - Anz
# 2     Senior Vice President and Chief Information Of...
# 3            Senior Learning and Development Specialist
# 4              Interim Global Chief Information Officer
# 7          Chief Information Officer at Parkview Health
# ...                                                 ...
# ...

# %%
file_name = 'matched.xlsx'
df11.to_excel(file_name)

# %%
def find_value_column(row):
    return row.First[-5:-8:-1][::-1] in row.COMPANYD

df12=df10[~df10.apply(find_value_column, axis=1)]

# %%
df12
# Out:
#                   FULL NAME    First Name  Last Name  \
# 1             Meggan Levitt       Meggan      Levitt
# 5                Jim Onalfo          Jim      Onalfo
# 6           Katherine Noyes    Katherine       Noyes
# 15           Stacy Whitmore        Stacy    Whitmore
# 16           Dale Jablonsky         Dale   Jablonsky
# ...                     ...           ...        ...
# 3481         Dorian Stevens       Dorian     Stevens
# 3483  Jean-Pierre Champigny  Jean-Pierre   Champigny
# 3484             Ric Hunter          Ric      Hunter
# 3486       Steven Fulkerson       Steven   Fulkerson
# 3487             Sam Segran          Sam      Segran
#
#                                               JOB TITLE  \
# 1     Assistant Vice Provost and Associate Chief Inf...
# 5                             Chief Information Officer
# 6     Senior Writer, Manager, Chief Information Offi...
# 15                  Learning and Development Specialist
# ...

# %%
file_name = 'Notmatched.xlsx'
df12.to_excel(file_name)

# %%
df20=pd.read_excel("C:/Users/admin/Desktop/new/working1.xlsx")

# %%
df20
# Out:
#              FULL NAME First Name  Last Name  \
# 0      Linda Iasouvanh     Linda   Iasouvanh
# 1        Meggan Levitt    Meggan      Levitt
# 2            Jeri Dunn      Jeri        Dunn
# 3            Jill Cook      Jill        Cook
# 4       Patrick Dineen   Patrick      Dineen
# ...                ...        ...        ...
# 3485        Nada Daman      Nada       Daman
# 3486  Steven Fulkerson    Steven   Fulkerson
# 3487        Sam Segran       Sam      Segran
# 3488      Diane Hanson     Diane      Hanson
# 3489      Debbie Dertz    Debbie       Dertz
#
#                                               JOB TITLE  \
# 0                Learning and Development Manager - Anz
# 1     Assistant Vice Provost and Associate Chief Inf...
# 2     Senior Vice President and Chief Information Of...
# 3            Senior Learning and Development Specialist
# 4              Interim Global Chief Information Officer
# ...                                                 ...
# ...

# %%
df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Human Resources'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Information Technology and Services'],'Technology')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Higher Education'],'Education')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Education Management'],'Education')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Writing and Editing'],'Marketing')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Hospital Health Care'],'Healthcare')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Military'],'Aerospace and Defense')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Investment Banking'],'Finance')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Financial Services'],'Finance')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Renewables Environment'],'Environment and Renewables')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Airlines/Aviation'],'Transportation')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Restaurants'],'Hospitality ')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Outsourcing/Offshoring'],'Supply Chain')


df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Renewables Environment'],'Energy and Mining and Raw Materials')


df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Professional Training Coaching'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Non-Profit Organization Management'],'Non-Profit')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Internet'],'Technology')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Construction'],'Manufacturing')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Computer Software'],'Technology')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Computer Networking'],'Technology')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Law Practice'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Pharmaceuticals'],'Healthcare')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Leisure, Travel, Tourism'],'Hospitality ')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Gambling Casinos'],'Hospitality')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Management Consulting'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Sporting Goods'],'Retail')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Executive Office'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Facilities Services'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Medical Devices'],'Healthcare')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Oil Energy'],'Energy and Mining and Raw Materials')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['E-Learning'],'Technology;Education')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Investment Management'],'Finance')



df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Consumer Electronics'],'Technology')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Apparel Fashion'],'Retail')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Telecommunications'],'Media and Telecommunications')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Security and Investigations'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Public Safety'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Accounting'],'Finance')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Research'],'Professional Services')


df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Information Services'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Computer Hardware'],'Technology')
df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Banking'],'Finance')
df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Environmental Services'],'Environment and Renewables')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Health, Wellness and Fitness'],'Healthcare')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Wholesale'],'Supply Chain')


df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Machinery'],'Manufacturing')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Primary/Secondary Education'],'Education')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Luxury Goods Jewelry'],'Retail')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Public Policy'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Events Services'],'Entertainment')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Program Development'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Legal Services'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Computer Network Security'],'Technology')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Biotechnology'],'Technology')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Chemicals'],'Energy and Mining and Raw Materials')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Computer Games'],'Technology')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Market Research'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Mining Metals'],'Energy and Mining and Raw Materials')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Civil Engineering'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Farming'],'Environment and Renewables')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Sports'],'Entertainment')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Real Estate'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Semiconductors'],'Manufacturing')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Broadcast Media'],'Media and Telecommunications')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Textiles'],'Manufacturing')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Maritime'],'Aerospace and Defense')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Medical Practice'],'Healthcare')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Staffing and Recruiting'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['International Affairs'],'International Development')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Publishing'],'Media and Telecommunications')
df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Wireless'],'Technology')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Packaging and Containers'],'Supply Chain')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Cosmetics'],'Retail')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Business Supplies and Equipment'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Commercial Real Estate'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Graphic Design'],'Marketing')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Warehousing'],' Supply Chain')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Individual Family Services'],'Education')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Media Production'],'Media and Telecommunications')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Glass, Ceramics, Concrete'],'Energy and Mining and Raw Materials')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Paper Forest Products'],'Environment and Renewables')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Public Relations and Communications'],'Media and Telecommunications')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Veterinary'],'Healthcare')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Animation'],'Technology')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Law Enforcement'],'Government and Federal')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Furniture'],'Manufacturing')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Recreational Facilities and Services'],'Entertainment')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Capital Markets'],'Finance')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Online Media'],'Media and Telecommunications')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Supermarkets'],'Retail')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Architecture Planning'],'Professional Services')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Venture Capital Private Equity'],'Finance')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Newspapers'],'Media and Telecommunications')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Railroad Manufacture'],'Transportation')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Religious Institutions'],'Non-Profit')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Design'],'Marketing')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Judiciary'],'Government and Federal')

df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace(['Photography'],'Entertainment')

#df10['COMPANY CATEGORY'] = dfs10['COMPANY CATEGORY'].replace(['Cosmetics'],'Retail')

# %%
df20
# Out:
#              FULL NAME First Name  Last Name  \
# 0      Linda Iasouvanh     Linda   Iasouvanh
# 1        Meggan Levitt    Meggan      Levitt
# 2            Jeri Dunn      Jeri        Dunn
# 3            Jill Cook      Jill        Cook
# 4       Patrick Dineen   Patrick      Dineen
# ...                ...        ...        ...
# 3485        Nada Daman      Nada       Daman
# 3486  Steven Fulkerson    Steven   Fulkerson
# 3487        Sam Segran       Sam      Segran
# 3488      Diane Hanson     Diane      Hanson
# 3489      Debbie Dertz    Debbie       Dertz
#
#                                               JOB TITLE  \
# 0                Learning and Development Manager - Anz
# 1     Assistant Vice Provost and Associate Chief Inf...
# 2     Senior Vice President and Chief Information Of...
# 3            Senior Learning and Development Specialist
# 4              Interim Global Chief Information Officer
# ...                                                 ...
# ...

# %%
l=df20['COMPANY CATEGORY'].unique()
for i in l:
    #if i=='Fine-Arts':
    print(i)
# Out:
# Professional Services
# Education
# Food Production
# Marketing and Advertising
# Government and Federal
# Marketing
# Healthcare
# Hospitality
# Finance
# Aerospace and Defense
# International Development
# Hospitality
# Transportation
# Media and Telecommunications
# Technology
# Supply Chain
# Environment and Renewables
# nan
# Insurance
# Non-Profit
# Manufacturing
# Retail
# Energy and Mining and Raw Materials
# Technology;Education
# Consumer Goods
# Entertainment
# Consumer Services
# Food Beverages
# Energy and Mining and raw Materials
# Printing

# %%
df20['COMPANY CATEGORY'] = df20['COMPANY CATEGORY'].replace([' Supply Chain'],'Supply Chain')

# %%
def find_value_column(row):
    return row.First[-5:-8:-1][::-1] in row.COMPANYD

df22=df20[~df20.apply(find_value_column, axis=1)]

# %%
df22
# Out:
#                   FULL NAME    First Name  Last Name  \
# 1             Meggan Levitt       Meggan      Levitt
# 5                Jim Onalfo          Jim      Onalfo
# 6           Katherine Noyes    Katherine       Noyes
# 15           Stacy Whitmore        Stacy    Whitmore
# 16           Dale Jablonsky         Dale   Jablonsky
# ...                     ...           ...        ...
# 3481         Dorian Stevens       Dorian     Stevens
# 3483  Jean-Pierre Champigny  Jean-Pierre   Champigny
# 3484             Ric Hunter          Ric      Hunter
# 3486       Steven Fulkerson       Steven   Fulkerson
# 3487             Sam Segran          Sam      Segran
#
#                                               JOB TITLE  \
# 1     Assistant Vice Provost and Associate Chief Inf...
# 5                             Chief Information Officer
# 6     Senior Writer, Manager, Chief Information Offi...
# 15                  Learning and Development Specialist
# ...

# %%
file_name = 'NotMatched.xlsx'
df22.to_excel(file_name)

# %%
xls = pd.ExcelFile('Fastbase_business_contacts_excel_699_HVVPQG.xlsx')
df30 = pd.read_excel(xls, 'Leads_search_02')

# %%
df30
# Out:
#             FULL NAME First Name  Last Name  \
# 0           Jeri Dunn      Jeri        Dunn
# 1          Jim Onalfo       Jim      Onalfo
# 2        James Benton     James      Benton
# 3       Terry Phillis     Terry     Phillis
# 4      Dale Jablonsky      Dale   Jablonsky
# ..                ...        ...        ...
# 609  Vincent Piccinni   Vincent    Piccinni
# 610       Damon Frost     Damon       Frost
# 611       Mindy Simon     Mindy       Simon
# 612        Joe Dumara       Joe      Dumara
# 613        Nada Daman      Nada       Daman
#
#                                              JOB TITLE          CITY  \
# 0    Senior Vice President and Chief Information Of...        Lowell
# 1                            Chief Information Officer      New York
# 2                            Chief Information Officer     Arlington
# 3    Chief Information Officer at City of Philadelphia  Philadelphia
# 4          Chief Information Officer Advisory Director    Sacramento
# ...

# %%
file_name = 'Leads_search2.xlsx'
df30.to_excel(file_name)
